# %%
import pandas as pd

# %matplotlib inline

from utilities.ml_metrics_charts import confusion_matrix_heatmap

# %%
data_dict = {'true': pd.Series(["a", "b", "c","a","a"]),
             'pred': pd.Series(["a", "b", "c","b","c"])}

df = pd.DataFrame(data_dict)

#y_true, y_pred
confusion_matrix_heatmap(df['true'].tolist(),df['pred'].tolist(),normalized=True)
